# %%
# %sql
-- Tạo catalog (nếu chưa có)
CREATE CATALOG IF NOT EXISTS soa_catalog;
USE CATALOG soa_catalog;
-- Tạo schema (database) cho ecommerce
CREATE SCHEMA IF NOT EXISTS soa_catalog.ecommerce;
USE soa_catalog.ecommerce;
-- Hiển thị schema hiện tại
SELECT current_schema();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>ecommerce</td></tr></tbody></table></div>
