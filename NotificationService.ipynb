# %%
dbutils.widgets.text("order_id", "0")
dbutils.widgets.text("user_id", "0")
order_id = dbutils.widgets.get("order_id")
user_id = dbutils.widgets.get("user_id")

message = f"NOTIFICATION sent: Order {order_id} for user {user_id} has been processed."
dbutils.notebook.exit(message)
# Out:
# NOTIFICATION sent: Order 0 for user 0 has been processed.
